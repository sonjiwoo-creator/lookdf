# %%
import pandas as pd 

orders = pd.read_csv("./orders_202604091310.csv")
distribution_centers = pd.read_csv("./distribution_centers_202604091311.csv")
events = pd.read_csv("./events_202604091311.csv")
inventory_items = pd.read_csv("./inventory_items_202604091311.csv")
order_items = pd.read_csv("./order_items_202604091310.csv")
products = pd.read_csv("./products_202604091309.csv")
users = pd.read_csv("./users_202604091308.csv")
# Out:
# C:\Users\usiro\AppData\Local\Temp\ipykernel_48880\2008713118.py:9: DtypeWarning: Columns (0: postal_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   users = pd.read_csv("./users_202604091308.csv")

# %%
orders
# Out:
#         order_id  user_id     status gender               created_at  \
# 0             28       20  Cancelled      F  2025-10-20 12:40:05 UTC
# 1             29       21  Cancelled      F  2025-07-04 02:15:52 UTC
# 2             68       53  Cancelled      F  2025-09-01 20:46:44 UTC
# 3             74       59  Cancelled      F  2025-05-04 00:17:07 UTC
# 4             80       63  Cancelled      F  2025-03-09 13:26:33 UTC
# ...          ...      ...        ...    ...                      ...
# 125242    125220    99971    Shipped      M  2024-06-22 22:12:08 UTC
# 125243    125222    99973    Shipped      M  2025-12-10 22:24:46 UTC
# 125244    125229    99979    Shipped      M  2022-03-11 22:32:10 UTC
# 125245    125231    99983    Shipped      M  2021-05-23 11:12:44 UTC
# 125246    125246    99999    Shipped      M  2025-11-30 17:57:11 UTC
#
#        returned_at               shipped_at delivered_at  num_of_item
# 0              NaN                      NaN          NaN            1
# 1              NaN                      NaN          NaN            1
# 2              NaN                      NaN          NaN            1
# 3              NaN                      NaN          NaN            2
# 4              NaN                      NaN          NaN            1
# ...            ...                      ...          ...          ...
# 125242         NaN  2024-06-25 18:53:08 UTC          NaN            1
# 125243         NaN  2025-12-12 17:35:46 UTC          NaN            2
# 125244         NaN  2022-03-14 11:39:10 UTC          NaN            1
# 125245         NaN  2021-05-26 09:31:44 UTC          NaN            1
# 125246         NaN  2025-12-02 04:25:11 UTC          NaN            2
#
# [125247 rows x 9 columns]
